# %% [markdown]
# # Employee Salaries 2022

# %% [markdown]
# ###### Import libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ##### Read the CSV file

# %%
data=pd.read_csv(r"C:\Users\UMAPRIYA\Desktop\Employee_Salaries_2022\Process\Employee_Salaries_-_2022.csv")

# %% [markdown]
# ### 1.Understanding the Data

# %%
data.head()
# Out:
#   Department            Department_Name  \
# 0        ABS  Alcohol Beverage Services
# 1        ABS  Alcohol Beverage Services
# 2        ABS  Alcohol Beverage Services
# 3        ABS  Alcohol Beverage Services
# 4        ABS  Alcohol Beverage Services
#
#                                      Division Gender  Base_Salary  \
# 0                                Beer Loading      M      87969.0
# 1         Liquor and Wine Delivery Operations      M      80086.0
# 2                    Beer Delivery Operations      M      80086.0
# 3                    Beer Delivery Operations      M      70814.0
# 4  Stock Liquor and Wine Warehouse Operations      M      76419.0
#
#    2022_Overtime_Pay  2022_Longevity_Pay Grade
# 0           32953.25                 NaN    20
# 1           32656.04             1105.44    18
# 2           31369.15             1591.20    18
# 3           29837.85                 NaN    18
# 4           21379.22                 NaN    17

# %%
data.tail()
# Out:
#      Department                                    Department_Name  \
# 9902        TBS  Department of Technology and Enterprise Busine...
# 9903        ZAH       Office of Zoning and Administrative Hearings
# 9904        ZAH       Office of Zoning and Administrative Hearings
# 9905        ZAH       Office of Zoning and Administrative Hearings
# 9906        ZAH       Office of Zoning and Administrative Hearings
#
#                                           Division Gender  Base_Salary  \
# 9902                 CIO Chief Information Officer      F    217000.00
# 9903  Office of Zoning and Administrative Hearings      F     72885.67
# 9904            Zoning and Administrative Hearings      F     92211.00
# 9905            Zoning and Administrative Hearings      M    142100.00
# 9906                                      Director      F    181930.63
#
#       2022_Overtime_Pay  2022_Longevity_Pay Grade
# 9902                NaN                 NaN     0
# 9903                NaN                 NaN    18
# 9904                NaN                 NaN    21
# 9905                NaN                 NaN    35
# 9906                NaN                 NaN     0

# %%
data.shape
# Out:
# (9907, 8)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9907 entries, 0 to 9906
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Department          9907 non-null   object
#  1   Department_Name     9907 non-null   object
#  2   Division            9907 non-null   object
#  3   Gender              9907 non-null   object
#  4   Base_Salary         9907 non-null   float64
#  5   2022_Overtime_Pay   5595 non-null   float64
#  6   2022_Longevity_Pay  2413 non-null   float64
#  7   Grade               9907 non-null   object
# dtypes: float64(3), object(5)
# memory usage: 619.3+ KB

# %%
data.columns
# Out:
# Index(['Department', 'Department_Name', 'Division', 'Gender', 'Base_Salary',
#        '2022_Overtime_Pay', '2022_Longevity_Pay', 'Grade'],
#       dtype='object')

# %%
data.nunique()
# Out:
# Department              40
# Department_Name         40
# Division               845
# Gender                   2
# Base_Salary           3225
# 2022_Overtime_Pay     5520
# 2022_Longevity_Pay     881
# Grade                   74
# dtype: int64

# %%
data.Department.unique()
# Out:
# array(['ABS', 'CCL', 'BOA', 'BOE', 'CAT', 'CEC', 'CEX', 'COR', 'FRS',
#        'CUS', 'DEP', 'DGS', 'DHS', 'DOT', 'DPS', 'ECM', 'FIN', 'HCA',
#        'NDA', 'HHS', 'HRC', 'IGR', 'LIB', 'MPB', 'OAG', 'OAS', 'OCP',
#        'OHR', 'OIG', 'OLO', 'OLR', 'OMB', 'PIO', 'ORE', 'POL', 'SHF',
#        'REC', 'PRO', 'TBS', 'ZAH'], dtype=object)

# %%
data.Department_Name.unique()
# Out:
# array(['Alcohol Beverage Services', 'County Council',
#        'Board of Appeals Department', 'Board of Elections',
#        "County Attorney's Office", 'Community Engagement Cluster',
#        'Offices of the County Executive', 'Correction and Rehabilitation',
#        'Fire and Rescue Services', 'Community Use of Public Facilities',
#        'Department of Environmental Protection',
#        'Department of General Services',
#        'Office of Emergency Management and Homeland Security',
#        'Department of Transportation',
#        'Department of Permitting Services', 'Ethics Commission',
#        'Department of Finance',
#        'Department of Housing and Community Affairs',
#        'Non-Departmental Account',
#        'Department of Health and Human Services',
#        'Office of Human Rights',
#        'Office of Intergovernmental Relations Department',
#        'Department of Public Libraries',
#        'Merit System Protection Board Department',
#        'Office of Agriculture', 'Office of Animal Services',
#        'Office of Consumer Protection', 'Office of Human Resources',
#        'Office of the Inspector General',
#        'Office of Legislative Oversight', 'Office of Labor Relations',
#        'Office of Management and Budget', 'Office of Public Information',
#        'Office of Racial Equity and Social Justice',
#        'Department of Police', "Sheriff's Office",
#        'Department of Recreation', 'Office of Procurement',
#        'Department of Technology and Enterprise Business Solutions',
#        'Office of Zoning and Administrative Hearings'], dtype=object)

# %%
data.Gender.unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
data.Grade.unique()
# Out:
# array(['20', '18', '17', '12', '15', '10', '13', '19', '22', '9', '21',
#        '14', '16', '23', '25', '26', 'M3', '28', 'M2', '0', 'M1', '5',
#        '27', '32', '24', 'C5', 'C6', 'C1', 'C4', 'C3', 'B1', 'C2', 'F3',
#        '11', 'F2', '8', '7', '30', 'F4', '29', 'B2', 'B3', 'F3P', 'F1',
#        'B4', 'B6', '36', 'MD3', 'MD4', '33', '39', 'MD2', '38', '31',
#        '40', 'P4', 'A1', 'G3', 'P5', 'A2', 'P3', 'P2', 'A3', 'D3', 'D4',
#        'P1', 'P4P', 'D1', 'G4', 'G2', 'D2', 'G1', '34', '35'],
#       dtype=object)

# %%
data.describe()
# Out:
#          Base_Salary  2022_Overtime_Pay  2022_Longevity_Pay
# count    9907.000000        5595.000000         2413.000000
# mean    81339.530378       10560.836633         3674.409030
# std     30639.336329       16255.130689         2251.749433
# min     11147.240000           1.000000           19.930000
# 25%     59939.000000        1090.960000         1981.280000
# 50%     78789.380000        4817.930000         3164.720000
# 75%     96665.000000       12668.925000         5419.680000
# max    262000.000000      219325.630000        12100.400000

# %% [markdown]
# ### 2.Cleaning the Data

# %%
data.isnull().sum()
# Out:
# Department               0
# Department_Name          0
# Division                 0
# Gender                   0
# Base_Salary              0
# 2022_Overtime_Pay     4312
# 2022_Longevity_Pay    7494
# Grade                    0
# dtype: int64

# %%
df =data.fillna(0)

# %%
df
# Out:
#      Department                                    Department_Name  \
# 0           ABS                          Alcohol Beverage Services
# 1           ABS                          Alcohol Beverage Services
# 2           ABS                          Alcohol Beverage Services
# 3           ABS                          Alcohol Beverage Services
# 4           ABS                          Alcohol Beverage Services
# ...         ...                                                ...
# 9902        TBS  Department of Technology and Enterprise Busine...
# 9903        ZAH       Office of Zoning and Administrative Hearings
# 9904        ZAH       Office of Zoning and Administrative Hearings
# 9905        ZAH       Office of Zoning and Administrative Hearings
# 9906        ZAH       Office of Zoning and Administrative Hearings
#
#                                           Division Gender  Base_Salary  \
# 0                                     Beer Loading      M     87969.00
# 1              Liquor and Wine Delivery Operations      M     80086.00
# 2                         Beer Delivery Operations      M     80086.00
# 3                         Beer Delivery Operations      M     70814.00
# 4       Stock Liquor and Wine Warehouse Operations      M     76419.00
# ...                                            ...    ...          ...
# 9902                 CIO Chief Information Officer      F    217000.00
# 9903  Office of Zoning and Administrative Hearings      F     72885.67
# 9904            Zoning and Administrative Hearings      F     92211.00
# 9905            Zoning and Administrative Hearings      M    142100.00
# 9906                                      Director      F    181930.63
#
#       2022_Overtime_Pay  2022_Longevity_Pay Grade
# 0              32953.25                0.00    20
# 1              32656.04             1105.44    18
# 2              31369.15             1591.20    18
# 3              29837.85                0.00    18
# 4              21379.22                0.00    17
# ...                 ...                 ...   ...
# 9902               0.00                0.00     0
# 9903               0.00                0.00    18
# 9904               0.00                0.00    21
# 9905               0.00                0.00    35
# 9906               0.00                0.00     0
#
# [9907 rows x 8 columns]

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9902    False
# 9903    False
# 9904    False
# 9905    False
# 9906    False
# Length: 9907, dtype: bool

# %% [markdown]
# ### 3.Relationship Analysis

# %%
df.corr(method ='pearson')
# Out:
# C:\Users\UMAPRIYA\AppData\Local\Temp\ipykernel_23960\2355739806.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr(method ='pearson')
#                     Base_Salary  2022_Overtime_Pay  2022_Longevity_Pay
# Base_Salary            1.000000           0.042312            0.241509
# 2022_Overtime_Pay      0.042312           1.000000            0.121532
# 2022_Longevity_Pay     0.241509           0.121532            1.000000

# %%
corelation=df.corr()
# Out:
# C:\Users\UMAPRIYA\AppData\Local\Temp\ipykernel_23960\3476424618.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corelation=df.corr()

# %%
import matplotlib.pyplot as plt

# %%
df.plot.area()
# Out:
# <AxesSubplot: >

# %%
sns.pairplot(df)

# %%
df.plot.box()
# Out:
# <AxesSubplot: >
